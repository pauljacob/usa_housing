# %%
import pandas as pd
import os
import json
import numpy as np

files = os.listdir()

# %%
files
# Out:
# ['.ipynb_checkpoints',
#  'all_available_metrics.json',
#  'cities_crosswalk.csv',
#  'City_time_series.csv',
#  'CountyCrossWalk_Zillow.csv',
#  'County_time_series.csv',
#  'DataDictionary.csv',
#  'fields_per_level.json',
#  'Metro_time_series.csv',
#  'Neighborhood_time_series.csv',
#  'State_time_series.csv',
#  'Untitled.ipynb',
#  'Untitled1.ipynb',
#  'Zip_time_series.csv']

# %%
#df = json.loads(files[1])
with open(files[1]) as json_file:
    data = json.load(json_file)

# %%
data
# Out:
# ['AgeOfInventory',
#  'Date',
#  'DaysOnZillow_AllHomes',
#  'InventoryRaw_AllHomes',
#  'InventorySeasonallyAdjusted_AllHomes',
#  'InventorySeasonallyAdjusted_BottomTier',
#  'InventorySeasonallyAdjusted_MiddleTier',
#  'InventorySeasonallyAdjusted_TopTier',
#  'InventoryTierShare_BottomTier_AllHomes',
#  'InventoryTierShare_MiddleTier_AllHomes',
#  'InventoryTierShare_TopTier_AllHomes',
#  'MedianListingPricePerSqft_1Bedroom',
#  'MedianListingPricePerSqft_2Bedroom',
#  'MedianListingPricePerSqft_3Bedroom',
#  'MedianListingPricePerSqft_4Bedroom',
#  'MedianListingPricePerSqft_5BedroomOrMore',
#  'MedianListingPricePerSqft_AllHomes',
#  'MedianListingPricePerSqft_CondoCoop',
#  'MedianListingPricePerSqft_DuplexTriplex',
#  'MedianListingPricePerSqft_SingleFamilyResidence',
#  'MedianListingPrice_1Bedroom',
#  'MedianListingPrice_2Bedroom',
#  'MedianListingPrice_3Bedroom',
#  'MedianListingPrice_4Bedroom',
#  'MedianListingPrice_5BedroomOrMore',
#  'MedianListingPrice_AllHomes',
# ...

# %%
with open(files[7]) as json_file:
    data2 = json.load(json_file)

# %%
data2
# Out:
# {'City': ['Date',
#   'InventoryRaw_AllHomes',
#   'InventorySeasonallyAdjusted_AllHomes',
#   'MedianListingPricePerSqft_1Bedroom',
#   'MedianListingPricePerSqft_2Bedroom',
#   'MedianListingPricePerSqft_3Bedroom',
#   'MedianListingPricePerSqft_4Bedroom',
#   'MedianListingPricePerSqft_5BedroomOrMore',
#   'MedianListingPricePerSqft_AllHomes',
#   'MedianListingPricePerSqft_CondoCoop',
#   'MedianListingPricePerSqft_DuplexTriplex',
#   'MedianListingPricePerSqft_SingleFamilyResidence',
#   'MedianListingPrice_1Bedroom',
#   'MedianListingPrice_2Bedroom',
#   'MedianListingPrice_3Bedroom',
#   'MedianListingPrice_4Bedroom',
#   'MedianListingPrice_5BedroomOrMore',
#   'MedianListingPrice_AllHomes',
#   'MedianListingPrice_CondoCoop',
#   'MedianListingPrice_DuplexTriplex',
#   'MedianListingPrice_SingleFamilyResidence',
#   'MedianPctOfPriceReduction_AllHomes',
#   'MedianPctOfPriceReduction_CondoCoop',
#   'MedianPctOfPriceReduction_SingleFamilyResidence',
# ...

# %%
#City
cities  = [files[2], files[3]]

# %%
cities
# Out:
# ['cities_crosswalk.csv', 'City_time_series.csv']

# %%
df = pd.read_csv(cities[0])

# %%
df
# Out:
#                 Unique_City_ID            City     County State
# 0         oak_grovechristianky       Oak Grove  Christian    KY
# 1        jarvisburgcurritucknc      Jarvisburg  Currituck    NC
# 2         mcminnvilleyamhillor     McMinnville    Yamhill    OR
# 3         union_townshiperiepa  Union Township       Erie    PA
# 4           oshkoshwinnebagowi         Oshkosh  Winnebago    WI
# ...                        ...             ...        ...   ...
# 25336       oakdalealleghenypa         Oakdale  Allegheny    PA
# 25337          benddeschutesor            Bend  Deschutes    OR
# 25338            stoutgrundyia           Stout     Grundy    IA
# 25339  collettsvillecaldwellnc   Collettsville   Caldwell    NC
# 25340         henricohenricova         Henrico    Henrico    VA
#
# [25341 rows x 4 columns]

# %%
df2 = pd.read_csv(cities[1])

# %%
df2
# Out:
#                Date             RegionName  \
# 0        1996-04-30     abbottstownadamspa
# 1        1996-04-30      aberdeenbinghamid
# 2        1996-04-30      aberdeenharfordmd
# 3        1996-04-30       aberdeenmonroems
# 4        1996-04-30        aberdeenmoorenc
# ...             ...                    ...
# 3762561  2017-12-31    zirconiahendersonnc
# 3762562  2017-12-31  zolfo_springshardeefl
# 3762563  2017-12-31  zumbro_fallswabashamn
# 3762564  2017-12-31      zumbrotagoodhuemn
# 3762565  2017-12-31    zuniisle_of_wightva
#
#          InventorySeasonallyAdjusted_AllHomes  InventoryRaw_AllHomes  \
# 0                                         NaN                    NaN
# 1                                         NaN                    NaN
# 2                                         NaN                    NaN
# 3                                         NaN                    NaN
# 4                                         NaN                    NaN
# ...

# %%
df2.columns
# Out:
# Index(['Date', 'RegionName', 'InventorySeasonallyAdjusted_AllHomes',
#        'InventoryRaw_AllHomes', 'MedianListingPricePerSqft_1Bedroom',
#        'MedianListingPricePerSqft_2Bedroom',
#        'MedianListingPricePerSqft_3Bedroom',
#        'MedianListingPricePerSqft_4Bedroom',
#        'MedianListingPricePerSqft_5BedroomOrMore',
#        'MedianListingPricePerSqft_AllHomes',
#        'MedianListingPricePerSqft_CondoCoop',
#        'MedianListingPricePerSqft_DuplexTriplex',
#        'MedianListingPricePerSqft_SingleFamilyResidence',
#        'MedianListingPrice_1Bedroom', 'MedianListingPrice_2Bedroom',
#        'MedianListingPrice_3Bedroom', 'MedianListingPrice_4Bedroom',
#        'MedianListingPrice_5BedroomOrMore', 'MedianListingPrice_AllHomes',
#        'MedianListingPrice_CondoCoop', 'MedianListingPrice_DuplexTriplex',
#        'MedianListingPrice_SingleFamilyResidence',
#        'MedianPctOfPriceReduction_AllHomes',
#        'MedianPctOfPriceReduction_CondoCoop',
# ...

# %%
df2['Sale_Prices'].count()
# Out:
# 147290

# %%
city_sale_data = df2[['RegionName','Sale_Prices']][~df2['Sale_Prices'].isnull()]
city_sale_data
# Out:
#                            RegionName  Sale_Prices
# 1880792             abingdonharfordmd     257400.0
# 1880797            abingtonplymouthma     270800.0
# 1880825              addisondu_pageil     243700.0
# 1880840               agawamhampdenma     207700.0
# 1880841     agoura_hillslos_angelesca     651300.0
# ...                               ...          ...
# 3762511     yorkshireprince_williamva     320500.0
# 3762517            yorkvillekendallil     222700.0
# 3762536       yucaipasan_bernardinoca     343500.0
# 3762537  yucca_valleysan_bernardinoca     168700.0
# 3762538               yukoncanadianok     165600.0
#
# [147290 rows x 2 columns]

# %% [markdown]
# <font color='red'> this median sale prices per city??????????????<font>

# %%
city_sale_data2 = df2[~df2['Sale_Prices'].isnull()]
city_sale_data2
# Out:
#                Date                    RegionName  \
# 1880792  2008-03-31             abingdonharfordmd
# 1880797  2008-03-31            abingtonplymouthma
# 1880825  2008-03-31              addisondu_pageil
# 1880840  2008-03-31               agawamhampdenma
# 1880841  2008-03-31     agoura_hillslos_angelesca
# ...             ...                           ...
# 3762511  2017-12-31     yorkshireprince_williamva
# 3762517  2017-12-31            yorkvillekendallil
# 3762536  2017-12-31       yucaipasan_bernardinoca
# 3762537  2017-12-31  yucca_valleysan_bernardinoca
# 3762538  2017-12-31               yukoncanadianok
#
#          InventorySeasonallyAdjusted_AllHomes  InventoryRaw_AllHomes  \
# 1880792                                   NaN                    NaN
# 1880797                                   NaN                    NaN
# 1880825                                   NaN                    NaN
# 1880840                                   NaN                    NaN
# ...

# %%
df2.info(null_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3762566 entries, 0 to 3762565
# Data columns (total 81 columns):
#  #   Column                                                         Non-Null Count    Dtype
# ---  ------                                                         --------------    -----
#  0   Date                                                           3762566 non-null  object
#  1   RegionName                                                     3762566 non-null  object
#  2   InventorySeasonallyAdjusted_AllHomes                           771744 non-null   float64
#  3   InventoryRaw_AllHomes                                          771744 non-null   float64
#  4   MedianListingPricePerSqft_1Bedroom                             7670 non-null     float64
#  5   MedianListingPricePerSqft_2Bedroom                             74574 non-null    float64
#  6   MedianListingPricePerSqft_3Bedroom                             250633 non-null   float64
# ...

# %%
city_sale_data.count()
# Out:
# RegionName     147290
# Sale_Prices    147290
# dtype: int64

# %%
city_count = len(city_sale_data['RegionName'].unique())

# %%
df
# Out:
#                 Unique_City_ID            City     County State
# 0         oak_grovechristianky       Oak Grove  Christian    KY
# 1        jarvisburgcurritucknc      Jarvisburg  Currituck    NC
# 2         mcminnvilleyamhillor     McMinnville    Yamhill    OR
# 3         union_townshiperiepa  Union Township       Erie    PA
# 4           oshkoshwinnebagowi         Oshkosh  Winnebago    WI
# ...                        ...             ...        ...   ...
# 25336       oakdalealleghenypa         Oakdale  Allegheny    PA
# 25337          benddeschutesor            Bend  Deschutes    OR
# 25338            stoutgrundyia           Stout     Grundy    IA
# 25339  collettsvillecaldwellnc   Collettsville   Caldwell    NC
# 25340         henricohenricova         Henrico    Henrico    VA
#
# [25341 rows x 4 columns]

# %%
import pandas as pd
import os
import json
import numpy as np

# %%
files = os.listdir()

# %%
files
# Out:
# ['.ipynb_checkpoints',
#  'all_available_metrics.json',
#  'cities_crosswalk.csv',
#  'City_time_series.csv',
#  'CountyCrossWalk_Zillow.csv',
#  'County_time_series.csv',
#  'DataDictionary.csv',
#  'fields_per_level.json',
#  'Metro_time_series.csv',
#  'Neighborhood_time_series.csv',
#  'State_time_series.csv',
#  'Untitled.ipynb',
#  'Zip_time_series.csv']

# %%
#df = json.loads(files[1])
with open(files[1]) as json_file:
    data = json.load(json_file)

# %%
data
# Out:
# ['AgeOfInventory',
#  'Date',
#  'DaysOnZillow_AllHomes',
#  'InventoryRaw_AllHomes',
#  'InventorySeasonallyAdjusted_AllHomes',
#  'InventorySeasonallyAdjusted_BottomTier',
#  'InventorySeasonallyAdjusted_MiddleTier',
#  'InventorySeasonallyAdjusted_TopTier',
#  'InventoryTierShare_BottomTier_AllHomes',
#  'InventoryTierShare_MiddleTier_AllHomes',
#  'InventoryTierShare_TopTier_AllHomes',
#  'MedianListingPricePerSqft_1Bedroom',
#  'MedianListingPricePerSqft_2Bedroom',
#  'MedianListingPricePerSqft_3Bedroom',
#  'MedianListingPricePerSqft_4Bedroom',
#  'MedianListingPricePerSqft_5BedroomOrMore',
#  'MedianListingPricePerSqft_AllHomes',
#  'MedianListingPricePerSqft_CondoCoop',
#  'MedianListingPricePerSqft_DuplexTriplex',
#  'MedianListingPricePerSqft_SingleFamilyResidence',
#  'MedianListingPrice_1Bedroom',
#  'MedianListingPrice_2Bedroom',
#  'MedianListingPrice_3Bedroom',
#  'MedianListingPrice_4Bedroom',
#  'MedianListingPrice_5BedroomOrMore',
#  'MedianListingPrice_AllHomes',
# ...

# %%
with open(files[7]) as json_file:
    data2 = json.load(json_file)

# %%
data2
# Out:
# {'City': ['Date',
#   'InventoryRaw_AllHomes',
#   'InventorySeasonallyAdjusted_AllHomes',
#   'MedianListingPricePerSqft_1Bedroom',
#   'MedianListingPricePerSqft_2Bedroom',
#   'MedianListingPricePerSqft_3Bedroom',
#   'MedianListingPricePerSqft_4Bedroom',
#   'MedianListingPricePerSqft_5BedroomOrMore',
#   'MedianListingPricePerSqft_AllHomes',
#   'MedianListingPricePerSqft_CondoCoop',
#   'MedianListingPricePerSqft_DuplexTriplex',
#   'MedianListingPricePerSqft_SingleFamilyResidence',
#   'MedianListingPrice_1Bedroom',
#   'MedianListingPrice_2Bedroom',
#   'MedianListingPrice_3Bedroom',
#   'MedianListingPrice_4Bedroom',
#   'MedianListingPrice_5BedroomOrMore',
#   'MedianListingPrice_AllHomes',
#   'MedianListingPrice_CondoCoop',
#   'MedianListingPrice_DuplexTriplex',
#   'MedianListingPrice_SingleFamilyResidence',
#   'MedianPctOfPriceReduction_AllHomes',
#   'MedianPctOfPriceReduction_CondoCoop',
#   'MedianPctOfPriceReduction_SingleFamilyResidence',
# ...

# %%
df = pd.read_csv('Zip_time_series.csv')

# %%
df
# Out:
#                Date  RegionName  InventorySeasonallyAdjusted_AllHomes  \
# 0        1996-04-30        1001                                   NaN
# 1        1996-04-30        1002                                   NaN
# 2        1996-04-30        1005                                   NaN
# 3        1996-04-30        1007                                   NaN
# 4        1996-04-30        1008                                   NaN
# ...             ...         ...                                   ...
# 4383880  2017-12-31       99709                                  57.0
# 4383881  2017-12-31       99712                                  43.0
# 4383882  2017-12-31       99801                                  80.0
# 4383883  2017-12-31       99835                                   NaN
# 4383884  2017-12-31       99901                                   NaN
#
#          InventoryRaw_AllHomes  MedianListingPricePerSqft_1Bedroom  \
# ...

# %%
pd.options.display.max_rows = 80

df.info(null_counts=True) #verbose=True
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4383885 entries, 0 to 4383884
# Data columns (total 76 columns):
#  #   Column                                                         Non-Null Count    Dtype
# ---  ------                                                         --------------    -----
#  0   Date                                                           4383885 non-null  object
#  1   RegionName                                                     4383885 non-null  int64
#  2   InventorySeasonallyAdjusted_AllHomes                           1051104 non-null  float64
#  3   InventoryRaw_AllHomes                                          1051104 non-null  float64
#  4   MedianListingPricePerSqft_1Bedroom                             8194 non-null     float64
#  5   MedianListingPricePerSqft_2Bedroom                             86554 non-null    float64
#  6   MedianListingPricePerSqft_3Bedroom                             384738 non-null   float64
# ...

# %%
df.iloc[:,4:9]
# Out:
#          MedianListingPricePerSqft_1Bedroom  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
# ...                                     ...
# 4383880                                 NaN
# 4383881                                 NaN
# 4383882                                 NaN
# 4383883                                 NaN
# 4383884                                 NaN
#
#          MedianListingPricePerSqft_2Bedroom  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
# ...                                     ...
# 4383880                                 NaN
# 4383881                                 NaN
# ...

# %%
a = df.iloc[:,13:22].count()
a
# Out:
# MedianListingPrice_1Bedroom                   7753
# MedianListingPrice_2Bedroom                  67724
# MedianListingPrice_3Bedroom                 317189
# MedianListingPrice_4Bedroom                 161600
# MedianListingPrice_5BedroomOrMore            27703
# MedianListingPrice_AllHomes                 627319
# MedianListingPrice_CondoCoop                 55646
# MedianListingPrice_DuplexTriplex             10171
# MedianListingPrice_SingleFamilyResidence    610481
# dtype: int64

# %%
b = df.iloc[:,4:13].count()
b
# Out:
# MedianListingPricePerSqft_1Bedroom                   8194
# MedianListingPricePerSqft_2Bedroom                  86554
# MedianListingPricePerSqft_3Bedroom                 384738
# MedianListingPricePerSqft_4Bedroom                 197581
# MedianListingPricePerSqft_5BedroomOrMore            33722
# MedianListingPricePerSqft_AllHomes                 814908
# MedianListingPricePerSqft_CondoCoop                 72778
# MedianListingPricePerSqft_DuplexTriplex              8092
# MedianListingPricePerSqft_SingleFamilyResidence    776613
# dtype: int64

# %%
a.sum()
# Out:
# 1885586

# %%
type(df.iloc[:,4:13].count())
# Out:
# pandas.core.series.Series

# %%
c = np.array([9,9,9,9,9,9,9,9,9])
c
# Out:
# array([9, 9, 9, 9, 9, 9, 9, 9, 9])

# %%
for i in range(0, len(b)):
    c[i] =  b.iloc[i] - a.iloc[i]
c
# Out:
# array([   441,  18830,  67549,  35981,   6019, 187589,  17132,  -2079,
#        166132])

# %%
moreThanSqft = df.iloc[:,13:22].count() - df.iloc[:,4:13].count()
moreThanSqft
# Out:
# MedianListingPricePerSqft_1Bedroom                NaN
# MedianListingPricePerSqft_2Bedroom                NaN
# MedianListingPricePerSqft_3Bedroom                NaN
# MedianListingPricePerSqft_4Bedroom                NaN
# MedianListingPricePerSqft_5BedroomOrMore          NaN
# MedianListingPricePerSqft_AllHomes                NaN
# MedianListingPricePerSqft_CondoCoop               NaN
# MedianListingPricePerSqft_DuplexTriplex           NaN
# MedianListingPricePerSqft_SingleFamilyResidence   NaN
# MedianListingPrice_1Bedroom                       NaN
# MedianListingPrice_2Bedroom                       NaN
# MedianListingPrice_3Bedroom                       NaN
# MedianListingPrice_4Bedroom                       NaN
# MedianListingPrice_5BedroomOrMore                 NaN
# MedianListingPrice_AllHomes                       NaN
# MedianListingPrice_CondoCoop                      NaN
# MedianListingPrice_DuplexTriplex                  NaN
# ...

# %%
df.describe().T
# Out:
#                                                         count           mean  \
# RegionName                                          4383885.0   46837.261770
# InventorySeasonallyAdjusted_AllHomes                1051104.0     123.049029
# InventoryRaw_AllHomes                               1051104.0     123.072143
# MedianListingPricePerSqft_1Bedroom                     8194.0     322.914946
# MedianListingPricePerSqft_2Bedroom                    86554.0     188.769142
# MedianListingPricePerSqft_3Bedroom                   384738.0     144.331279
# MedianListingPricePerSqft_4Bedroom                   197581.0     154.549637
# MedianListingPricePerSqft_5BedroomOrMore              33722.0     223.571617
# MedianListingPricePerSqft_AllHomes                   814908.0     158.755338
# MedianListingPricePerSqft_CondoCoop                   72778.0     273.766816
# MedianListingPricePerSqft_DuplexTriplex                8092.0     228.069518
# ...

# %%
df['RegionName'].hist()

# %%
df['InventoryRaw_AllHomes']
# Out:
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN
#            ...
# 4383880    34.0
# 4383881    30.0
# 4383882    74.0
# 4383883     NaN
# 4383884     NaN
# Name: InventoryRaw_AllHomes, Length: 4383885, dtype: float64

# %%
df[0:3].T
# Out:
#                                                              0           1  \
# Date                                                1996-04-30  1996-04-30
# RegionName                                                1001        1002
# InventorySeasonallyAdjusted_AllHomes                       NaN         NaN
# InventoryRaw_AllHomes                                      NaN         NaN
# MedianListingPricePerSqft_1Bedroom                         NaN         NaN
# MedianListingPricePerSqft_2Bedroom                         NaN         NaN
# MedianListingPricePerSqft_3Bedroom                         NaN         NaN
# MedianListingPricePerSqft_4Bedroom                         NaN         NaN
# MedianListingPricePerSqft_5BedroomOrMore                   NaN         NaN
# MedianListingPricePerSqft_AllHomes                         NaN         NaN
# MedianListingPricePerSqft_CondoCoop                        NaN         NaN
# ...
